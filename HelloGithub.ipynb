# %%
print "Hello Github"
# Out:
#   File "<ipython-input-1-2aa125d1a9df>", line 1
#     print "Hello Github"
#                        ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello Github")?

# %%
print('Hello Github')
# Out:
# Hello Github
